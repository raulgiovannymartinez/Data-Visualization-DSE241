# %%
import pandas as pd
from os.path import join
from os import path, listdir

# %%
df = pd.read_csv('../dash_plotly_code/data/data.csv')

# %%
fp = path.abspath('../dash_plotly_code/data/raw')

# %%
df
# Out:
#          State     County                 Time  Dose_Rate  Gamma_Count
# 0           AK  ANCHORAGE  06/05/2008 00:49:00        NaN       1322.0
# 1           AK  ANCHORAGE  06/05/2008 01:49:00        NaN       1215.0
# 2           AK  ANCHORAGE  06/05/2008 02:50:00        NaN       1223.0
# 3           AK  ANCHORAGE  06/05/2008 03:50:00        NaN       1238.0
# 4           AK  ANCHORAGE  06/05/2008 04:50:00        NaN       1266.0
# ...        ...        ...                  ...        ...          ...
# 11617845    WY     CASPER  12/27/2020 11:37:00      108.0       5932.0
# 11617846    WY     CASPER  12/27/2020 12:38:00      109.0       5882.0
# 11617847    WY     CASPER  12/27/2020 13:38:00      109.0       5807.0
# 11617848    WY     CASPER  12/27/2020 14:38:00      110.0       6079.0
# 11617849    WY     CASPER  12/27/2020 15:38:00      111.0       6201.0
#
# [11617850 rows x 5 columns]

# %%
locations = df[['State','County']]
locations = locations.drop_duplicates()
locations
# Out:
#          State      County
# 0           AK   ANCHORAGE
# 86375       AK   FAIRBANKS
# 160285      AK      JUNEAU
# 234110      AL  BIRMINGHAM
# 333397      AL      MOBILE
# ...        ...         ...
# 11211553    WI     MADISON
# 11300466    WI   MILWAUKEE
# 11405155    WI     SHAWANO
# 11472344    WV  CHARLESTON
# 11567226    WY      CASPER
#
# [140 rows x 2 columns]

# %%
cities = pd.read_csv('Data/uscities.csv')
cities['city'] = cities['city'].str.upper() 
cities.head(5)
# Out:
#           city   city_ascii state_id  state_name  county_fips  county_name  \
# 0     New York     New York       NY    New York        36061     New York
# 1  Los Angeles  Los Angeles       CA  California         6037  Los Angeles
# 2      Chicago      Chicago       IL    Illinois        17031         Cook
# 3        Miami        Miami       FL     Florida        12086   Miami-Dade
# 4       Dallas       Dallas       TX       Texas        48113       Dallas
#
#        lat       lng  population  density   source  military  incorporated  \
# 0  40.6943  -73.9249    18713220    10715  polygon     False          True
# 1  34.1139 -118.4068    12750807     3276  polygon     False          True
# 2  41.8373  -87.6862     8604203     4574  polygon     False          True
# 3  25.7839  -80.2102     6445545     5019  polygon     False          True
# 4  32.7936  -96.7662     5743938     1526  polygon     False          True
#
#               timezone  ranking  \
# ...

# %%
new_df = pd.merge(locations, cities,  how='left', left_on=['State','County'], right_on = ['state_id','city'])
new_df
# Out:
#     State      County        city  city_ascii state_id     state_name  \
# 0      AK   ANCHORAGE   ANCHORAGE   Anchorage       AK         Alaska
# 1      AK   FAIRBANKS   FAIRBANKS   Fairbanks       AK         Alaska
# 2      AK      JUNEAU      JUNEAU      Juneau       AK         Alaska
# 3      AL  BIRMINGHAM  BIRMINGHAM  Birmingham       AL        Alabama
# 4      AL      MOBILE      MOBILE      Mobile       AL        Alabama
# ..    ...         ...         ...         ...      ...            ...
# 135    WI     MADISON     MADISON     Madison       WI      Wisconsin
# 136    WI   MILWAUKEE   MILWAUKEE   Milwaukee       WI      Wisconsin
# 137    WI     SHAWANO     SHAWANO     Shawano       WI      Wisconsin
# 138    WV  CHARLESTON  CHARLESTON  Charleston       WV  West Virginia
# 139    WY      CASPER      CASPER      Casper       WY        Wyoming
#
#      county_fips           county_name      lat       lng  population  \
# ...

# %%
new_df = new_df.drop(['city_ascii','state_id','state_name','county_fips','county_name','population','density','source','military','incorporated','ranking','zips','id'],axis=1)
new_df
# Out:
#     State      County        city      lat       lng           timezone
# 0      AK   ANCHORAGE   ANCHORAGE  61.1508 -149.1091  America/Anchorage
# 1      AK   FAIRBANKS   FAIRBANKS  64.8353 -147.6534  America/Anchorage
# 2      AK      JUNEAU      JUNEAU  58.4546 -134.1739     America/Juneau
# 3      AL  BIRMINGHAM  BIRMINGHAM  33.5277  -86.7987    America/Chicago
# 4      AL      MOBILE      MOBILE  30.6783  -88.1162    America/Chicago
# ..    ...         ...         ...      ...       ...                ...
# 135    WI     MADISON     MADISON  43.0826  -89.3931    America/Chicago
# 136    WI   MILWAUKEE   MILWAUKEE  43.0642  -87.9673    America/Chicago
# 137    WI     SHAWANO     SHAWANO  44.7748  -88.5843    America/Chicago
# 138    WV  CHARLESTON  CHARLESTON  38.3484  -81.6323   America/New_York
# 139    WY      CASPER      CASPER  42.8420 -106.3207     America/Denver
#
# [140 rows x 6 columns]

# %%
new_df.to_csv('locations.csv')
